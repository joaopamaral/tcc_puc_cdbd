# %% [markdown]
# <a href="https://colab.research.google.com/github/joaopamaral/tcc_puc_cdbd/blob/master/Analise_Storybook_CENIPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise dados CENIPA para construção do Storybook
#
# ![Descrição CENIPA](https://raw.githubusercontent.com/zezente/opendata_aig_brazil/master/reference/data_model.png)

# %% [markdown]
# ## Importando as bibliotecas utilizadas

# %%
import pandas as pd
import folium
from folium import plugins
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# %%
# Removendo warning de depreciação do matlab utilizado no Seaborn
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %% [markdown]
# ## Realizando leitura dos dados da CENIPA

# %%
def get_cenipa_data():
    """Retorna os dados abertos da Cenipa em dataframes"""
    cenipa_url = 'http://sistema.cenipa.aer.mil.br/cenipa/media/opendata'

    oco_df = pd.read_csv(f'{cenipa_url}/oco.csv', sep='~', index_col='codigo_ocorrencia', parse_dates=['ocorrencia_dia'])
    ftc_df = pd.read_csv(f'{cenipa_url}/ftc.csv', sep='~')
    rec_df = pd.read_csv(f'{cenipa_url}/rec.csv', sep='~')
    anv_df = pd.read_csv(f'{cenipa_url}/anv.csv', sep='~')

    return oco_df, ftc_df, rec_df, anv_df

oco_df, ftc_df, rec_df, anv_df = get_cenipa_data()

# %% [markdown]
# ### Análise Preliminar dos dados

# %%
print(f'Total de dados na tabela de Ocorrências: {oco_df.shape[0]}')
print(f'Total de dados na tabela de Fatores Contribuintes: {ftc_df.shape[0]}')
print(f'Total de dados na tabela de Recomendações de Segurança: {rec_df.shape[0]}')
print(f'Total de dados na tabela de Aeronaves Envolvidas: {anv_df.shape[0]}')
# Out:
# Total de dados na tabela de Ocorrências: 5460
# Total de dados na tabela de Fatores Contribuintes: 4630
# Total de dados na tabela de Recomendações de Segurança: 2059
# Total de dados na tabela de Aeronaves Envolvidas: 5523

# %%
print(f'Total de ocorrências sem dados em Fatores Contribuintes: {(~oco_df.index.isin(ftc_df.codigo_ocorrencia)).sum()}')
print(f'Total de ocorrências sem dados em Aeronaves Envolvidas: {(~oco_df.index.isin(anv_df.codigo_ocorrencia)).sum()}')
# Out:
# Total de ocorrências sem dados em Fatores Contribuintes: 4334
# Total de ocorrências sem dados em Aeronaves Envolvidas: 0

# %%
print('Dados Faltantes Tabela de Ocorrências: \n')
display(oco_df.isna().sum()[oco_df.isna().sum() > 0])

print('\nDados Faltantes Fatores Contribuintes: \n')
display(ftc_df.isna().sum()[ftc_df.isna().sum() > 0])

print('\nDados Faltantes Recomendações de Segurança: \n')
display(rec_df.isna().sum()[rec_df.isna().sum() > 0])

print('\nDados Faltantes Aeronaves Envolvidas: \n')
display(anv_df.isna().sum()[anv_df.isna().sum() > 0])
# Out:
# Dados Faltantes Tabela de Ocorrências:
# investigacao_aeronave_liberada    3941
# divulgacao_dia_publicacao         4085
# dtype: int64
# Dados Faltantes Fatores Contribuintes:
# fator_detalhe_fator    1920
# dtype: int64
# Dados Faltantes Recomendações de Segurança:
# recomendacao_dia_assinatura          2
# recomendacao_dia_encaminhamento    195
# recomendacao_feedback              567
# dtype: int64
# Dados Faltantes Aeronaves Envolvidas:
# aeronave_assentos           119
# aeronave_ano_fabricacao      69
# aeronave_pais_fabricante     45
# dtype: int64

# %%
print(f'Total de dados duplicados na tabela de Ocorrências: {oco_df.duplicated().sum()}')
print(f'Total de dados duplicados na tabela de Fatores Contribuintes: {ftc_df.duplicated().sum()}')
print(f'Total de dados duplicados na tabela de Recomendações de Segurança: {rec_df.duplicated().sum()}')
print(f'Total de dados duplicados na tabela de Aeronaves Envolvidas: {anv_df.duplicated().sum()}')
# Out:
# Total de dados duplicados na tabela de Ocorrências: 0
# Total de dados duplicados na tabela de Fatores Contribuintes: 0
# Total de dados duplicados na tabela de Recomendações de Segurança: 3
# Total de dados duplicados na tabela de Aeronaves Envolvidas: 0

# %% [markdown]
# ### Analisando principais fatores (max top 15 por visualização)

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,10))

for i, col in enumerate(['fator_nome', 'fator_aspecto', 'fator_condicionante', 'fator_area']):
    sns.countplot(y=col, data=ftc_df, order=ftc_df[col].value_counts().iloc[:15].index, ax=ax[i // 2][i % 2])
    ax[i // 2][i % 2].set(xlabel='Contagem', ylabel=col.replace('_', ' ').title())

fig.suptitle('Análise dos principais fatores das ocorrência', fontsize=16)
fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# ### Realizando join da tabela de fatores e concatenando as colunas de fatores

# %%
for col in ['fator_nome', 'fator_aspecto', 'fator_condicionante', 'fator_area']:
    oco_df = oco_df.join(ftc_df[['codigo_ocorrencia', col]].drop_duplicates().groupby('codigo_ocorrencia')[col].apply(', '.join))

# %%
oco_df.loc[:, oco_df.columns.str.contains('fator_')]
# Out:
#                                                           fator_nome  \
# codigo_ocorrencia
# 201305055424986                                                  NaN
# 201311259977425        COORDENAÇÃO DE CABINE, ESQUECIMENTO DO PILOTO
# 201605160250139    PERCEPÇÃO, PROCESSO DECISÓRIO, PROCESSOS ORGAN...
# 201805021421302                                                  NaN
# 201103187273112                                                  NaN
# ...                                                              ...
# 201107163514591                                                  NaN
# 201101107541931                                                  NaN
# 201502247981603                                                  NaN
# 200910311058203                                                  NaN
# 201309012098180    APLICAÇÃO DE COMANDOS, CONDIÇÕES METEOROLÓGICA...
#
#                                                    fator_aspecto  \
# codigo_ocorrencia
# 201305055424986                                              NaN
# 201311259977425                         DESEMPENHO DO SER HUMANO
# 201605160250139    ASPECTO PSICOLÓGICO, DESEMPENHO DO SER HUMANO
# 201805021421302                                              NaN
# 201103187273112                                              NaN
# ...                                                          ...
# 201107163514591                                              NaN
# 201101107541931                                              NaN
# 201502247981603                                              NaN
# 200910311058203                                              NaN
# 201309012098180                    DESEMPENHO DO SER HUMANO, ***
#
#                                                 fator_condicionante  \
# codigo_ocorrencia
# 201305055424986                                                 NaN
# 201311259977425                                OPERAÇÃO DA AERONAVE
# 201605160250139    INDIVIDUAL, ORGANIZACIONAL, OPERAÇÃO DA AERONAVE
# 201805021421302                                                 NaN
# 201103187273112                                                 NaN
# ...                                                             ...
# 201107163514591                                                 NaN
# 201101107541931                                                 NaN
# 201502247981603                                                 NaN
# 200910311058203                                                 NaN
# 201309012098180                           OPERAÇÃO DA AERONAVE, ***
#
#                                         fator_area
# codigo_ocorrencia
# 201305055424986                                NaN
# 201311259977425                  FATOR OPERACIONAL
# 201605160250139    FATOR HUMANO, FATOR OPERACIONAL
# 201805021421302                                NaN
# 201103187273112                                NaN
# ...                                            ...
# 201107163514591                                NaN
# 201101107541931                                NaN
# 201502247981603                                NaN
# 200910311058203                                NaN
# 201309012098180             FATOR OPERACIONAL, ***
#
# [5460 rows x 4 columns]

# %% [markdown]
# ### Adicionando o total de fatalidades a análise

# %%
oco_df = oco_df.join(anv_df.groupby('codigo_ocorrencia')['total_fatalidades'].sum())

# %%
print(f'Quantidade de ocorrências: {oco_df.shape[0]}')
print(f'Ocorrências registradas de {oco_df.ocorrencia_dia.min().date()} a {oco_df.ocorrencia_dia.max().date()}')
display(oco_df.head())
print('\n')
display(oco_df.describe(include='all'))
# Out:
# Quantidade de ocorrências: 5460
# Ocorrências registradas de 2009-01-01 a 2019-05-29
#                   ocorrencia_classificacao  \
# codigo_ocorrencia
# 201305055424986                   ACIDENTE
# 201311259977425            INCIDENTE GRAVE
# 201605160250139            INCIDENTE GRAVE
# 201805021421302                  INCIDENTE
# 201103187273112                  INCIDENTE
#
#                                                      ocorrencia_tipo  \
# codigo_ocorrencia
# 201305055424986                                FALHA DO MOTOR EM VOO
# 201311259977425                                       POUSO SEM TREM
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
# 201103187273112                                               OUTROS
#
#                                            ocorrencia_tipo_categoria  \
# codigo_ocorrencia
# 201305055424986                  FALHA OU MAU FUNCIONAMENTO DO MOTOR
# 201311259977425                          CONTATO ANORMAL COM A PISTA
# 201605160250139    COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 201805021421302                                            AERÓDROMO
# 201103187273112                                               OUTROS
#
#                   ocorrencia_tipo_icao  ocorrencia_latitude  \
# codigo_ocorrencia
# 201305055424986                 SCF-PP              -9.9085
# 201311259977425                    ARC             -11.4956
# 201605160250139                   CTOL             -11.2644
# 201805021421302                   ADRM             -11.4956
# 201103187273112                   OTHR             -13.1950
#
#                    ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia
# 201305055424986                -63.0333         ARIQUEMES            RO
# 201311259977425                -61.4508            CACOAL            RO
# 201605160250139                -61.2589            CACOAL            RO
# 201805021421302                -61.4508            CACOAL            RO
# 201103187273112                -60.8184        CEREJEIRAS            RO
#
#                   ocorrencia_pais ocorrencia_aerodromo  ...  \
# codigo_ocorrencia                                       ...
# 201305055424986            BRASIL                 SJOG  ...
# 201311259977425            BRASIL                 SSKW  ...
# 201605160250139            BRASIL                 SSKW  ...
# 201805021421302            BRASIL                 SSKW  ...
# 201103187273112            BRASIL                 ****  ...
#
#                   divulgacao_dia_publicacao total_recomendacoes  \
# codigo_ocorrencia
# 201305055424986                         NaN                   0
# 201311259977425                  2014-04-07                   0
# 201605160250139                  2019-03-11                   7
# 201805021421302                         NaN                   0
# 201103187273112                         NaN                   0
#
#                   total_aeronaves_envolvidas ocorrencia_saida_pista  \
# codigo_ocorrencia
# 201305055424986                            1                    NÃO
# 201311259977425                            1                    NÃO
# 201605160250139                            1                    NÃO
# 201805021421302                            1                    NÃO
# 201103187273112                            1                    NÃO
#
#                   ocorrencia_dia_extracao  \
# codigo_ocorrencia
# 201305055424986                2019-05-31
# 201311259977425                2019-05-31
# 201605160250139                2019-05-31
# 201805021421302                2019-05-31
# 201103187273112                2019-05-31
#
#                                                           fator_nome  \
# codigo_ocorrencia
# 201305055424986                                                  NaN
# 201311259977425        COORDENAÇÃO DE CABINE, ESQUECIMENTO DO PILOTO
# 201605160250139    PERCEPÇÃO, PROCESSO DECISÓRIO, PROCESSOS ORGAN...
# 201805021421302                                                  NaN
# 201103187273112                                                  NaN
#
#                                                    fator_aspecto  \
# codigo_ocorrencia
# 201305055424986                                              NaN
# 201311259977425                         DESEMPENHO DO SER HUMANO
# 201605160250139    ASPECTO PSICOLÓGICO, DESEMPENHO DO SER HUMANO
# 201805021421302                                              NaN
# 201103187273112                                              NaN
#
#                                                 fator_condicionante  \
# codigo_ocorrencia
# 201305055424986                                                 NaN
# 201311259977425                                OPERAÇÃO DA AERONAVE
# 201605160250139    INDIVIDUAL, ORGANIZACIONAL, OPERAÇÃO DA AERONAVE
# 201805021421302                                                 NaN
# 201103187273112                                                 NaN
#
#                                         fator_area total_fatalidades
# codigo_ocorrencia
# 201305055424986                                NaN                 0
# 201311259977425                  FATOR OPERACIONAL                 0
# 201605160250139    FATOR HUMANO, FATOR OPERACIONAL                 0
# 201805021421302                                NaN                 0
# 201103187273112                                NaN                 0
#
# [5 rows x 26 columns]
#        ocorrencia_classificacao        ocorrencia_tipo  \
# count                      5460                   5460
# unique                        3                     71
# top                   INCIDENTE  FALHA DO MOTOR EM VOO
# freq                       3073                    651
# first                       NaN                    NaN
# last                        NaN                    NaN
# mean                        NaN                    NaN
# std                         NaN                    NaN
# min                         NaN                    NaN
# 25%                         NaN                    NaN
# 50%                         NaN                    NaN
# 75%                         NaN                    NaN
# max                         NaN                    NaN
#
#                                 ocorrencia_tipo_categoria  \
# count                                                5460
# unique                                                 31
# top     FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
# freq                                                 1160
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        ocorrencia_tipo_icao  ocorrencia_latitude  ocorrencia_longitude  \
# count                  5460          5460.000000           5460.000000
# unique                   29                  NaN                   NaN
# top                  SCF-NP                  NaN                   NaN
# freq                   1723                  NaN                   NaN
# first                   NaN                  NaN                   NaN
# last                    NaN                  NaN                   NaN
# mean                    NaN           -18.193427            -47.492499
# std                     NaN             8.894486             10.949421
# min                     NaN          -224.164700            -72.781100
# 25%                     NaN           -23.330300            -51.171100
# 50%                     NaN           -21.145550            -47.880000
# 75%                     NaN           -14.752025            -43.995600
# max                     NaN            55.582200             69.850600
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo  \
# count               5460          5460            5460                 5460
# unique              1050            28               1                  480
# top       RIO DE JANEIRO            SP          BRASIL                 ****
# freq                 319          1310            5460                 2172
# first                NaN           NaN             NaN                  NaN
# last                 NaN           NaN             NaN                  NaN
# mean                 NaN           NaN             NaN                  NaN
# std                  NaN           NaN             NaN                  NaN
# min                  NaN           NaN             NaN                  NaN
# 25%                  NaN           NaN             NaN                  NaN
# 50%                  NaN           NaN             NaN                  NaN
# 75%                  NaN           NaN             NaN                  NaN
# max                  NaN           NaN             NaN                  NaN
#
#         ... divulgacao_dia_publicacao total_recomendacoes  \
# count   ...                      1375         5460.000000
# unique  ...                       213                 NaN
# top     ...                2017-08-01                 NaN
# freq    ...                        62                 NaN
# first   ...                       NaN                 NaN
# last    ...                       NaN                 NaN
# mean    ...                       NaN            0.378571
# std     ...                       NaN            1.350778
# min     ...                       NaN            0.000000
# 25%     ...                       NaN            0.000000
# 50%     ...                       NaN            0.000000
# 75%     ...                       NaN            0.000000
# max     ...                       NaN           23.000000
#
#        total_aeronaves_envolvidas ocorrencia_saida_pista  \
# count                 5460.000000                   5460
# unique                        NaN                      2
# top                           NaN                    NÃO
# freq                          NaN                   5009
# first                         NaN                    NaN
# last                          NaN                    NaN
# mean                     1.011538                    NaN
# std                      0.115062                    NaN
# min                      1.000000                    NaN
# 25%                      1.000000                    NaN
# 50%                      1.000000                    NaN
# 75%                      1.000000                    NaN
# max                      4.000000                    NaN
#
#        ocorrencia_dia_extracao              fator_nome  \
# count                     5460                    1126
# unique                       1                     654
# top                 2019-05-31  MANUTENÇÃO DE AERONAVE
# freq                      5460                      63
# first                      NaN                     NaN
# last                       NaN                     NaN
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#                    fator_aspecto   fator_condicionante         fator_area  \
# count                       1126                  1126               1126
# unique                        64                    88                 19
# top     DESEMPENHO DO SER HUMANO  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# freq                         518                   355                553
# first                        NaN                   NaN                NaN
# last                         NaN                   NaN                NaN
# mean                         NaN                   NaN                NaN
# std                          NaN                   NaN                NaN
# min                          NaN                   NaN                NaN
# 25%                          NaN                   NaN                NaN
# 50%                          NaN                   NaN                NaN
# 75%                          NaN                   NaN                NaN
# max                          NaN                   NaN                NaN
#
#        total_fatalidades
# count        5460.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# first                NaN
# last                 NaN
# mean            0.157875
# std             0.784059
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max            24.000000
#
# [13 rows x 26 columns]

# %% [markdown]
# ## Analisando as ocorrências no Brasil

# %% [markdown]
# ### Análise temporal das ocorrências

# %%
fig, ax = plt.subplots(figsize=(10,5))
oco_df.groupby([oco_df.ocorrencia_dia.dt.year, 'ocorrencia_classificacao'])['ocorrencia_tipo'].count().unstack().plot.bar(
    stacked=True, title="Quantidade de ocorrências registradas pelo CENIPA", ax=ax);
ax.set(xlabel="");

# %% [markdown]
# ### Análise geográfica das ocorrências

# %%
def plot_heatmap_brazil(lat_log_data, title):
    print(title)
    fig = folium.Figure(width=700, height=500, title=title)
    m=folium.Map([-15.4647,-47.5547], zoom_start=4)
    # plot heatmap
    m.add_child(plugins.HeatMap(lat_log_data, radius=15))
    m.add_to(fig)
    return fig

plot_heatmap_brazil(oco_df[['ocorrencia_latitude', 'ocorrencia_longitude']].values, title='Localização das Ocorrências no Brasil')
# Out:
# Localização das Ocorrências no Brasil
# <iframe src="about:blank" width="700" height="500"style="border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
filtro_fator_humano = (oco_df.fator_area.str.contains('FATOR HUMANO') | oco_df.fator_aspecto.str.contains('DESEMPENHO DO SER HUMANO'))
oco_df['FATOR HUMANO'] = filtro_fator_humano
location_data_humano = oco_df.loc[filtro_fator_humano, ['ocorrencia_latitude', 'ocorrencia_longitude']].values

plot_heatmap_brazil(location_data_humano, title='Localização das Ocorrências no Brasil devido o Fator Humano')
# Out:
# Localização das Ocorrências no Brasil devido o Fator Humano
# <iframe src="about:blank" width="700" height="500"style="border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# ### Análise dos fatores

# %%
display(ftc_df.head())
print('\n')
display(ftc_df.describe(include='all'))
# Out:
#    codigo_ocorrencia               fator_nome             fator_aspecto  \
# 0    200901015424167  JULGAMENTO DE PILOTAGEM  DESEMPENHO DO SER HUMANO
# 1    200901015424167   MANUTENÇÃO DE AERONAVE  DESEMPENHO DO SER HUMANO
# 2    200901015424167     SUPERVISÃO GERENCIAL  DESEMPENHO DO SER HUMANO
# 3    200901055963381                  ATITUDE       ASPECTO PSICOLÓGICO
# 4    200901055963381       PROCESSO DECISÓRIO       ASPECTO PSICOLÓGICO
#
#       fator_condicionante         fator_area  \
# 0    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 1  MANUTENÇÃO DA AERONAVE  FATOR OPERACIONAL
# 2    OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 3              INDIVIDUAL       FATOR HUMANO
# 4              INDIVIDUAL       FATOR HUMANO
#
#                                  fator_detalhe_fator fator_dia_extracao
# 0  A PROVÁVEL INTENÇÃO EM PRESERVAR A AERONAVE, C...         2019-05-31
# 1  O RELATÓRIO TÉCNICO DO IAE REVELOU FALHAS ORIU...         2019-05-31
# 2  O OPERADOR NÃO PROGRAMOU A REALIZAÇÃO DE INSPE...         2019-05-31
# 3  O PILOTO ERA POUCO EXPERIENTE E REALIZOU O POU...         2019-05-31
# 4  A POUCA EXPERIÊNCIA DO PILOTO, ALIADA AO EXCES...         2019-05-31
#         codigo_ocorrencia               fator_nome             fator_aspecto  \
# count        4.630000e+03                     4630                      4630
# unique                NaN                       68                        10
# top                   NaN  JULGAMENTO DE PILOTAGEM  DESEMPENHO DO SER HUMANO
# freq                  NaN                      583                      2782
# mean         2.012628e+14                      NaN                       NaN
# std          2.533158e+11                      NaN                       NaN
# min          2.009010e+14                      NaN                       NaN
# 25%          2.010121e+14                      NaN                       NaN
# 50%          2.012100e+14                      NaN                       NaN
# 75%          2.015020e+14                      NaN                       NaN
# max          2.019011e+14                      NaN                       NaN
#
#          fator_condicionante         fator_area fator_detalhe_fator  \
# count                   4630               4630                2710
# unique                     7                  4                2685
# top     OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL                SUMA
# freq                    2496               2866                  10
# mean                     NaN                NaN                 NaN
# std                      NaN                NaN                 NaN
# min                      NaN                NaN                 NaN
# 25%                      NaN                NaN                 NaN
# 50%                      NaN                NaN                 NaN
# 75%                      NaN                NaN                 NaN
# max                      NaN                NaN                 NaN
#
#        fator_dia_extracao
# count                4630
# unique                  1
# top            2019-05-31
# freq                 4630
# mean                  NaN
# std                   NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN

# %% [markdown]
# #### Impacto do fator humano em relação ao total de fatalidades

# %%
# Create 2x2 sub plots
gs = gridspec.GridSpec(2, 2)

fig = plt.figure(figsize=(15, 10))
ax1 = plt.subplot(gs[0, 0]) # row 0, col 0
ax2 = plt.subplot(gs[0, 1]) # row 0, col 1
ax3 = plt.subplot(gs[1, :]) # row 1, span all columns

fatal_df = pd.DataFrame([oco_df.loc[filtro_fator_humano, 'total_fatalidades'].sum(), 
                         oco_df.loc[~filtro_fator_humano, 'total_fatalidades'].sum()], ['FATOR HUMANO', 'OUTROS FATORES'], ['TOTAL DE FATALIDADES'])
display(fatal_df)
print('\n\n')

oco_df['FATOR HUMANO'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax1, labels=['OUTROS FATORES', 'FATOR HUMANO']);
sns.countplot(x='ocorrencia_classificacao', hue='FATOR HUMANO', data=oco_df, ax=ax3)
fatal_df['TOTAL DE FATALIDADES'].plot.pie(autopct='%1.1f%%', ax=ax2);

ax1.set_title('Fator humano em relação ao número de ocorrências')
ax2.set_title('Fator humano em relação a classificação da ocorrência')
ax3.set_title('Fator humano em relação ao número de fatalidade')

fig.suptitle('Análise dos principais fatores das ocorrência', fontsize=16)
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
#                 TOTAL DE FATALIDADES
# FATOR HUMANO                     486
# OUTROS FATORES                   376
